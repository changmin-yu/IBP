# %%
import numpy as np
import matplotlib.pyplot as plt

from utils.data import binary_LDS

# %matplotlib inline
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
X, weights = binary_LDS(num_samples=100, noise_scale=0.1, binary_prob=0.3)

# %%
fig, ax = plt.subplots(10, 10, figsize=(20, 20))

for i in range(100):
    ax[i // 10, i % 10].imshow(X[i].reshape(6, 6), cmap="gray", vmin=0.0, vmax=1.0)
    ax[i // 10, i % 10].set_xticks([])
    ax[i // 10, i % 10].set_yticks([])

# %%
weights[9]
# Out:
# array([0, 0, 0, 0, 0])
